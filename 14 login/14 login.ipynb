# %%
import logging

# %%
# logging.basicConfig(level=logging.DEBUG)
logging.debug('This is a debug message ')
logging.error("This is a error message")
logging.info("This is a info message")
logging.critical('This is a critical message')
# Out:
# 2026-09-10 21:03:54-root-DEBUG-This is a debug message
# 2026-09-10 21:03:54-root-ERROR-This is a error message
# 2026-09-10 21:03:54-root-INFO-This is a info message
# 2026-09-10 21:03:54-root-CRITICAL-This is a critical message

# %% [markdown]
# **Basic Congig**

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

logging.debug('This is a debug message')
logging.error('This is an error message')
logging.info('This is an info message')
logging.critical('This is a critical message')
# Out:
# 2026-09-10 19:53:11-root-DEBUG-This is a debug message
# 2026-09-10 19:53:11-root-ERROR-This is an error message
# 2026-09-10 19:53:11-root-INFO-This is an info message
# 2026-09-10 19:53:11-root-CRITICAL-This is a critical message
